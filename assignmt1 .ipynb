# %%
string1="hello"
string2="aleesha"

# %%
print(string1+string2)
# Out:
# helloaleesha

# %%
string3="welcome to python programming"

# %%
result=(string1+string2+string3)

# %%
print(result)
# Out:
# helloaleeshawelcome to python programming

# %%
print(result[0])
# Out:
# h

# %%
print(result[-1])
# Out:
# g

# %%
print(result[:5])
# Out:
# hello

# %%
print(result[-11:])
# Out:
# programming

# %%
print(result[6:11])
# Out:
# leesh

# %%
print(result[0:5])
# Out:
# hello

# %%
print(result[::-1])
# Out:
# gnimmargorp nohtyp ot emoclewahseelaolleh

# %%
print(result[23:29])
# Out:
# python

# %%
strM="python begginer tuitorial"

# %%
print(strM.upper())
# Out:
# PYTHON BEGGINER TUITORIAL

# %%
print(strM.lower())
# Out:
# python begginer tuitorial

# %%
print(strM.capitalize())
# Out:
# Python begginer tuitorial

# %%
print(strM.count("t"))
# Out:
# 3

# %%
print(strM.replace("python","machine learning"))
# Out:
# machine learning begginer tuitorial

# %%
t1=(10,20,30)

# %%
t2=(40,50,60)

# %%
t_combine=t1+t2

# %%
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
